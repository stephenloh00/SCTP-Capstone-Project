# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # The Objective of the exercise:
# #### To practice data cleaning and data manipulation on a data set
# #### To gain insights on the data set
# #### This is a generated data for data cleaning exercise, which contains data on an online ecommerce store.
# #### Finding: The sales peformance, patterns and insights of this ecommerce dataset over the past 5 yearsT

# %% [markdown]
# # Step 1. Importing the Online Sales Dataset for a deeper observation of the dataset

# %%
#loading the dataset
df = pd.read_csv('online_sales_dataset.csv')
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# 0           1.71     37039.0       Australia  0.470000  Bank Transfer
# 1          41.25     19144.0           Spain  0.190000        paypall
# 2          29.11     50472.0         Germany  0.350000  Bank Transfer
# 3          76.68     96586.0     Netherlands  0.140000        paypall
# 4         -68.11         NaN  United Kingdom  1.501433  Bank Transfer
# ...          ...         ...             ...       ...            ...
# 49777      70.92     51445.0           Spain  0.200000    Credit Card
# 49778      51.74     28879.0   United States  0.230000  Bank Transfer
# 49779      85.25     21825.0        Portugal  0.200000  Bank Transfer
# 49780      39.64     43199.0  United Kingdom  0.310000        paypall
# 49781      38.27     53328.0          France  0.100000    Credit Card
#
#        ShippingCost     Category SalesChannel  ReturnStatus ShipmentProvider  \
# 0             10.79      Apparel     In-store  Not Returned              UPS
# 1              9.51  Electronics       Online  Not Returned              UPS
# 2             23.03  Electronics       Online      Returned              UPS
# 3             11.08  Accessories       Online  Not Returned       Royal Mail
# 4               NaN  Electronics     In-store  Not Returned            FedEx
# ...             ...          ...          ...           ...              ...
# 49777          8.96  Electronics       Online      Returned              UPS
# 49778         23.55  Electronics       Online  Not Returned            FedEx
# 49779         16.26    Furniture     In-store  Not Returned            FedEx
# 49780         28.56      Apparel       Online  Not Returned       Royal Mail
# 49781          9.13   Stationery       Online  Not Returned              UPS
#
#       WarehouseLocation OrderPriority
# 0                London        Medium
# 1                  Rome        Medium
# 2                Berlin          High
# 3                  Rome           Low
# 4                   NaN        Medium
# ...                 ...           ...
# 49777            Berlin        Medium
# 49778         Amsterdam           Low
# 49779            London          High
# 49780            London        Medium
# 49781              Rome           Low
#
# [49782 rows x 17 columns]

# %% [markdown]
# ### 1.1 Performing EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49782 entries, 0 to 49781
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          49782 non-null  int64
#  1   StockCode          49782 non-null  object
#  2   Description        49782 non-null  object
#  3   Quantity           49782 non-null  int64
#  4   InvoiceDate        49782 non-null  object
#  5   UnitPrice          49782 non-null  float64
#  6   CustomerID         44804 non-null  float64
#  7   Country            49782 non-null  object
#  8   Discount           49782 non-null  float64
#  9   PaymentMethod      49782 non-null  object
#  10  ShippingCost       47293 non-null  float64
#  11  Category           49782 non-null  object
#  12  SalesChannel       49782 non-null  object
#  13  ReturnStatus       49782 non-null  object
#  14  ShipmentProvider   49782 non-null  object
#  15  WarehouseLocation  46297 non-null  object
#  16  OrderPriority      49782 non-null  object
# dtypes: float64(4), int64(2), object(11)
# memory usage: 6.5+ MB

# %%
df.describe()
# Out:
#            InvoiceNo      Quantity     UnitPrice    CustomerID      Discount  \
# count   49782.000000  49782.000000  49782.000000  44804.000000  49782.000000
# mean   550681.239946     22.372343     47.537862  55032.871775      0.275748
# std    260703.009944     17.917774     33.479510  25913.660157      0.230077
# min    100005.000000    -50.000000    -99.980000  10001.000000      0.000000
# 25%    324543.000000     11.000000     23.592500  32750.750000      0.130000
# 50%    552244.000000     23.000000     48.920000  55165.000000      0.260000
# 75%    776364.000000     37.000000     74.610000  77306.250000      0.380000
# max    999997.000000     49.000000    100.000000  99998.000000      1.999764
#
#        ShippingCost
# count  47293.000000
# mean      17.494529
# std        7.220557
# min        5.000000
# 25%       11.220000
# 50%       17.500000
# 75%       23.720000
# max       30.000000

# %%
#InvoiceDate is object dtype. To change to datetime64 format
#CustomerID is float64. last digit .0 is redundant. to remove and change to int64 format.
#Discount can be rounded to 2 decimal places. Negative values has also been observed in about 10% of the records in Discount feature.
#New Columns can be added for deeper analyis. sales_amt = Quantity x UnitPrice | sales_amt_discounted = Quantity x (UnitPrice x Discount)
#typo error in PaymentMethod. (paypall instead of PayPal)

# %%
df.isna().sum()
# Out:
# InvoiceNo               0
# StockCode               0
# Description             0
# Quantity                0
# InvoiceDate             0
# UnitPrice               0
# CustomerID           4978
# Country                 0
# Discount                0
# PaymentMethod           0
# ShippingCost         2489
# Category                0
# SalesChannel            0
# ReturnStatus            0
# ShipmentProvider        0
# WarehouseLocation    3485
# OrderPriority           0
# dtype: int64

# %%
#CustomerID has null values. Replace with '0'
#ShippingCost has null values. Replace with median value of ShippingCost
#WarehouseLocation has null values. Replace with 'Unknown'

# %% [markdown]
# # Step 2. Begin Data Cleansing and Transformation

# %% [markdown]
# ### 2.1 Changing InvoiceDate dtype to  datetime64 format

# %%
#InvoiceDate is object dtype. To change to datetime64 format
print("Before Conversion:", df['InvoiceDate'].dtype)

df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
# Out:
# Before Conversion: object

# %%
print("After Conversion:", df['InvoiceDate'].dtype)
# Out:
# After Conversion: datetime64[ns]

# %% [markdown]
# ### 2.2 Filling in null values and changing CustomerID to Integer format

# %%
#CustomerID is float64. last digit .0 is redundant. to remove and change to int format.

#handling the null values first in CustomerID.
df['CustomerID'].fillna(0, inplace=True)

# %%
#Converting CustomerID to int with astype function.
df['CustomerID'] = df['CustomerID'].round().astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49782 entries, 0 to 49781
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          49782 non-null  int64
#  1   StockCode          49782 non-null  object
#  2   Description        49782 non-null  object
#  3   Quantity           49782 non-null  int64
#  4   InvoiceDate        49782 non-null  datetime64[ns]
#  5   UnitPrice          49782 non-null  float64
#  6   CustomerID         49782 non-null  int32
#  7   Country            49782 non-null  object
#  8   Discount           49782 non-null  float64
#  9   PaymentMethod      49782 non-null  object
#  10  ShippingCost       47293 non-null  float64
#  11  Category           49782 non-null  object
#  12  SalesChannel       49782 non-null  object
#  13  ReturnStatus       49782 non-null  object
#  14  ShipmentProvider   49782 non-null  object
#  15  WarehouseLocation  46297 non-null  object
#  16  OrderPriority      49782 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(2), object(10)
# memory usage: 6.3+ MB

# %% [markdown]
# ### 2.3 Rounding off Discount to 2 decimal places

# %%
#Discount can be rounded to 2 decimal places.
df["Discount"] = df["Discount"].round(2)
display(df["Discount"])
# Out:
# 0        0.47
# 1        0.19
# 2        0.35
# 3        0.14
# 4        1.50
#          ...
# 49777    0.20
# 49778    0.23
# 49779    0.20
# 49780    0.31
# 49781    0.10
# Name: Discount, Length: 49782, dtype: float64

# %% [markdown]
# ### 2.4 Replacing null values in WarehouseLocation

# %%
#WarehouseLocation has null values. Replace with 'Unknown'
df['WarehouseLocation'].fillna('Unknown', inplace=True)
display(df["WarehouseLocation"])
# Out:
# 0           London
# 1             Rome
# 2           Berlin
# 3             Rome
# 4          Unknown
#            ...
# 49777       Berlin
# 49778    Amsterdam
# 49779       London
# 49780       London
# 49781         Rome
# Name: WarehouseLocation, Length: 49782, dtype: object

# %% [markdown]
# ### 2.5 Replacing null values in ShippingCost

# %%
#ShippingCost has null values. Replace with median value of ShippingCost
df.describe()
# Out:
#            InvoiceNo      Quantity          InvoiceDate     UnitPrice  \
# count   49782.000000  49782.000000                49782  49782.000000
# mean   550681.239946     22.372343  2022-11-03 02:30:00     47.537862
# min    100005.000000    -50.000000  2020-01-01 00:00:00    -99.980000
# 25%    324543.000000     11.000000  2021-06-02 13:15:00     23.592500
# 50%    552244.000000     23.000000  2022-11-03 02:30:00     48.920000
# 75%    776364.000000     37.000000  2024-04-04 15:45:00     74.610000
# max    999997.000000     49.000000  2025-09-05 05:00:00    100.000000
# std    260703.009944     17.917774                  NaN     33.479510
#
#          CustomerID      Discount  ShippingCost
# count  49782.000000  49782.000000  47293.000000
# mean   49529.805693      0.275750     17.494529
# min        0.000000      0.000000      5.000000
# 25%    25227.250000      0.130000     11.220000
# 50%    50025.500000      0.260000     17.500000
# 75%    74794.500000      0.380000     23.720000
# max    99998.000000      2.000000     30.000000
# std    29613.149485      0.230086      7.220557

# %%
df['ShippingCost'].median()
# Out:
# 17.5

# %%
df['ShippingCost'].fillna(df['ShippingCost'].median(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49782 entries, 0 to 49781
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          49782 non-null  int64
#  1   StockCode          49782 non-null  object
#  2   Description        49782 non-null  object
#  3   Quantity           49782 non-null  int64
#  4   InvoiceDate        49782 non-null  datetime64[ns]
#  5   UnitPrice          49782 non-null  float64
#  6   CustomerID         49782 non-null  int32
#  7   Country            49782 non-null  object
#  8   Discount           49782 non-null  float64
#  9   PaymentMethod      49782 non-null  object
#  10  ShippingCost       49782 non-null  float64
#  11  Category           49782 non-null  object
#  12  SalesChannel       49782 non-null  object
#  13  ReturnStatus       49782 non-null  object
#  14  ShipmentProvider   49782 non-null  object
#  15  WarehouseLocation  49782 non-null  object
#  16  OrderPriority      49782 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(2), object(10)
# memory usage: 6.3+ MB

# %% [markdown]
# ### 2.6 Correcting a spelling error in PaymentMethod. (PayPal misspelled as paypall)

# %%
# Correct the typo error in the 'payment_method' column 
df['PaymentMethod'] = df['PaymentMethod'].str.replace('paypall', 'PayPal')
df.head()
# Out:
#    InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 0     221958  SKU_1964   White Mug        38 2020-01-01 00:00:00       1.71
# 1     771155  SKU_1241   White Mug        18 2020-01-01 01:00:00      41.25
# 2     231932  SKU_1501  Headphones        49 2020-01-01 02:00:00      29.11
# 3     465838  SKU_1760   Desk Lamp        14 2020-01-01 03:00:00      76.68
# 4     359178  SKU_1386   USB Cable       -30 2020-01-01 04:00:00     -68.11
#
#    CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# 0       37039       Australia      0.47  Bank Transfer         10.79
# 1       19144           Spain      0.19         PayPal          9.51
# 2       50472         Germany      0.35  Bank Transfer         23.03
# 3       96586     Netherlands      0.14         PayPal         11.08
# 4           0  United Kingdom      1.50  Bank Transfer         17.50
#
#       Category SalesChannel  ReturnStatus ShipmentProvider WarehouseLocation  \
# 0      Apparel     In-store  Not Returned              UPS            London
# 1  Electronics       Online  Not Returned              UPS              Rome
# 2  Electronics       Online      Returned              UPS            Berlin
# 3  Accessories       Online  Not Returned       Royal Mail              Rome
# 4  Electronics     In-store  Not Returned            FedEx           Unknown
#
#   OrderPriority
# 0        Medium
# 1        Medium
# 2          High
# 3           Low
# 4        Medium

# %% [markdown]
# ### 2.7 Handling Abnormal Discount Values in Discount Feature.
# There are some records showing abnormal discount levels in the dataset. Discount levels of over 1 doesn't make sense as company will be selling
# As the number of affected values is small and no determinant to ascertain if it was a data-entry erroneous input, we have decided to cap the discount level at 1 if the value exceeds 1.

# %%
#determining total number of affected records with discount levels above 1.
discount_over_100 = df[df['Discount'] > 1]

# Calculate frequency
count_over_100 = len(discount_over_100)
total_records = len(df)
percentage_over_100 = (count_over_100 / total_records) * 100

# Display frequency and percentage
print(f"Number of records with discount > 100%: {count_over_100}") #less than 2% of the total records affected 992/49,782
# Out:
# Number of records with discount > 100%: 992

# %%
#Capping the discount level values to only 1 if value exceeds 1

df['Discount'] = df['Discount'].apply(lambda x: min(x, 1))
df.head()
# Out:
#    InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 0     221958  SKU_1964   White Mug        38 2020-01-01 00:00:00       1.71
# 1     771155  SKU_1241   White Mug        18 2020-01-01 01:00:00      41.25
# 2     231932  SKU_1501  Headphones        49 2020-01-01 02:00:00      29.11
# 3     465838  SKU_1760   Desk Lamp        14 2020-01-01 03:00:00      76.68
# 4     359178  SKU_1386   USB Cable       -30 2020-01-01 04:00:00     -68.11
#
#    CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# 0       37039       Australia      0.47  Bank Transfer         10.79
# 1       19144           Spain      0.19         PayPal          9.51
# 2       50472         Germany      0.35  Bank Transfer         23.03
# 3       96586     Netherlands      0.14         PayPal         11.08
# 4           0  United Kingdom      1.00  Bank Transfer         17.50
#
#       Category SalesChannel  ReturnStatus ShipmentProvider WarehouseLocation  \
# 0      Apparel     In-store  Not Returned              UPS            London
# 1  Electronics       Online  Not Returned              UPS              Rome
# 2  Electronics       Online      Returned              UPS            Berlin
# 3  Accessories       Online  Not Returned       Royal Mail              Rome
# 4  Electronics     In-store  Not Returned            FedEx           Unknown
#
#   OrderPriority
# 0        Medium
# 1        Medium
# 2          High
# 3           Low
# 4        Medium

# %% [markdown]
# ### 2.8 Handling Negative Values in Quantity & UnitPrice Features
# Some of the values in Quantity & UnitPrices are recorded in negative values. This is likely an error as products cannot be sold in a negative quantity and price.

# %%
#To correct this, we need to change all the negative values in the Quantity and UnitPrice features to positive.
#All negative values will transform to absolute values.
df['Quantity'] = df['Quantity'].abs()
df['UnitPrice'] = df['UnitPrice'].abs()

# %%
df.sample(30)
# Out:
#        InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 33229     778544  SKU_1104       White Mug         9 2023-10-16 13:00:00
# 42365     957215  SKU_1349       Desk Lamp        16 2024-10-31 05:00:00
# 4467      279838  SKU_1482       Desk Lamp        35 2020-07-05 03:00:00
# 25743     234918  SKU_1206       USB Cable        28 2022-12-08 15:00:00
# 49043     303247  SKU_1174        Backpack         6 2025-08-05 11:00:00
# 49578     782684  SKU_1184      Wall Clock        49 2025-08-27 18:00:00
# 29296     212046  SKU_1643      Headphones        47 2023-05-05 16:00:00
# 40527     119295  SKU_1520         T-shirt        24 2024-08-15 15:00:00
# 37362     332454  SKU_1595        Notebook        37 2024-04-05 18:00:00
# 38065     967794  SKU_1015        Backpack        14 2024-05-05 01:00:00
# 39186     242287  SKU_1790       White Mug        38 2024-06-20 18:00:00
# 23469     452646  SKU_1780         T-shirt        37 2022-09-04 21:00:00
# 2338      395286  SKU_1195        Backpack         2 2020-04-07 10:00:00
# 27824     426186  SKU_1064  Wireless Mouse         5 2023-03-05 08:00:00
# 34203     135925  SKU_1337        Backpack         3 2023-11-26 03:00:00
# 41782     482621  SKU_1741        Notebook        27 2024-10-06 22:00:00
# 18537     731359  SKU_1696         T-shirt         8 2022-02-11 09:00:00
# 42268     314579  SKU_1553       USB Cable        35 2024-10-27 04:00:00
# 4540      953284  SKU_1182       USB Cable        46 2020-07-08 04:00:00
# 40414     597220  SKU_1987       USB Cable        34 2024-08-10 22:00:00
# 36506     282600  SKU_1296        Blue Pen        36 2024-03-01 02:00:00
# 44685     171605  SKU_1070         T-shirt        18 2025-02-04 21:00:00
# 15217     337225  SKU_1678        Notebook        11 2021-09-26 01:00:00
# 22147     187846  SKU_1455      Wall Clock        32 2022-07-11 19:00:00
# 33270     743051  SKU_1587      Wall Clock        44 2023-10-18 06:00:00
# 17847     973993  SKU_1921      Headphones        18 2022-01-13 15:00:00
# 41229     144810  SKU_1307      Headphones         3 2024-09-13 21:00:00
# 43555     663940  SKU_1974       Desk Lamp        16 2024-12-19 19:00:00
# 40617     460694  SKU_1108       Desk Lamp        26 2024-08-19 09:00:00
# 9272      981809  SKU_1739         T-shirt        31 2021-01-21 08:00:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# 33229      82.91       94975        Portugal      0.22         PayPal
# 42365       1.27       98968     Netherlands      0.08    Credit Card
# 4467       31.87       89000           Italy      0.17         PayPal
# 25743      22.91       48848          Sweden      0.48  Bank Transfer
# 49043      55.33       52527     Netherlands      0.26    Credit Card
# 49578      15.66       51228     Netherlands      0.37    Credit Card
# 29296      49.73       82125  United Kingdom      0.02    Credit Card
# 40527      30.17       49063           Spain      0.16         PayPal
# 37362       8.46       56066  United Kingdom      0.11  Bank Transfer
# 38065      99.21       94187           Spain      0.18  Bank Transfer
# 39186      73.87       32769        Portugal      0.12    Credit Card
# 23469      57.20       80474         Belgium      0.18  Bank Transfer
# 2338        1.04           0     Netherlands      0.12    Credit Card
# 27824      54.17       61875   United States      0.41         PayPal
# 34203      60.27       91713          Norway      0.39    Credit Card
# 41782      44.62       95502           Italy      0.23  Bank Transfer
# 18537      69.18       27472  United Kingdom      0.01    Credit Card
# 42268      46.90       20883   United States      0.08         PayPal
# 4540       85.38       89272     Netherlands      0.21         PayPal
# 40414      84.22       33956           Italy      0.21  Bank Transfer
# 36506      66.33       57277          Sweden      0.05         PayPal
# 44685      20.96       52915           Italy      0.28         PayPal
# 15217      17.50           0  United Kingdom      0.23  Bank Transfer
# 22147      45.88       42142         Germany      0.10    Credit Card
# 33270      15.59       91449           Spain      0.21    Credit Card
# 17847       1.35       29320           Italy      0.02         PayPal
# 41229      55.62       46740          Norway      0.22  Bank Transfer
# 43555      32.82       90906         Germany      0.35    Credit Card
# 40617      59.68       84167          Norway      0.15    Credit Card
# 9272       67.15       60938         Germany      0.27  Bank Transfer
#
#        ShippingCost     Category SalesChannel  ReturnStatus ShipmentProvider  \
# 33229         15.04   Stationery       Online  Not Returned              DHL
# 42365         27.82  Accessories     In-store  Not Returned              DHL
# 4467          21.06  Accessories       Online  Not Returned              DHL
# 25743          9.95  Electronics     In-store  Not Returned              DHL
# 49043         14.54   Stationery       Online  Not Returned              UPS
# 49578         27.70    Furniture       Online  Not Returned       Royal Mail
# 29296         17.19      Apparel     In-store  Not Returned       Royal Mail
# 40527          8.40   Stationery     In-store  Not Returned              DHL
# 37362         20.51      Apparel       Online  Not Returned            FedEx
# 38065         11.14      Apparel       Online  Not Returned              UPS
# 39186          5.18  Accessories       Online  Not Returned            FedEx
# 23469         19.16  Electronics     In-store      Returned              DHL
# 2338          17.50  Accessories       Online  Not Returned              DHL
# 27824          8.32  Accessories     In-store  Not Returned            FedEx
# 34203         22.91   Stationery     In-store  Not Returned              DHL
# 41782         17.32  Accessories       Online  Not Returned       Royal Mail
# 18537         15.87    Furniture       Online  Not Returned       Royal Mail
# 42268         17.58  Electronics       Online  Not Returned       Royal Mail
# 4540          20.67    Furniture     In-store  Not Returned       Royal Mail
# 40414          9.20  Accessories     In-store      Returned              DHL
# 36506         26.52   Stationery     In-store  Not Returned       Royal Mail
# 44685         28.07  Accessories       Online  Not Returned              DHL
# 15217         17.50      Apparel       Online  Not Returned       Royal Mail
# 22147         11.82  Electronics     In-store  Not Returned              UPS
# 33270         17.21  Electronics     In-store  Not Returned              UPS
# 17847          5.17  Electronics     In-store  Not Returned       Royal Mail
# 41229         15.59  Electronics     In-store  Not Returned       Royal Mail
# 43555         20.17      Apparel       Online  Not Returned              DHL
# 40617         22.74   Stationery       Online      Returned       Royal Mail
# 9272          21.35  Electronics     In-store  Not Returned       Royal Mail
#
#       WarehouseLocation OrderPriority
# 33229         Amsterdam          High
# 42365         Amsterdam        Medium
# 4467               Rome           Low
# 25743             Paris           Low
# 49043              Rome           Low
# 49578             Paris          High
# 29296              Rome           Low
# 40527             Paris          High
# 37362            Berlin        Medium
# 38065             Paris           Low
# 39186         Amsterdam          High
# 23469            London           Low
# 2338            Unknown           Low
# 27824            Berlin          High
# 34203         Amsterdam        Medium
# 41782             Paris        Medium
# 18537            Berlin          High
# 42268            London          High
# 4540               Rome           Low
# 40414              Rome           Low
# 36506              Rome           Low
# 44685            London          High
# 15217           Unknown        Medium
# 22147         Amsterdam          High
# 33270             Paris        Medium
# 17847             Paris          High
# 41229             Paris           Low
# 43555              Rome           Low
# 40617             Paris        Medium
# 9272             Berlin           Low

# %% [markdown]
# ### 2.9 Creating new features Sales and Sales_Discounted + Year, Quarter, Month

# %%
# Adding Sales and Sales_Discounted Columns from calculations of Quantity, UnitPrice and Discount 
df['Sales'] = df['Quantity'] * df['UnitPrice']
df['Sales_Discounted'] = (df['Quantity'] * df['UnitPrice']) * (1 - df['Discount'])

# Adding Year, Quarter and Month Columns from InvoiceDate Column
df['Year'] = df['InvoiceDate'].dt.year 
df['Quarter'] = 'Q' + df['InvoiceDate'].dt.quarter.astype(str)
df['MonthNum'] = df['InvoiceDate'].dt.month
df['Month'] = df['InvoiceDate'].dt.strftime('%b')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49782 entries, 0 to 49781
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          49782 non-null  int64
#  1   StockCode          49782 non-null  object
#  2   Description        49782 non-null  object
#  3   Quantity           49782 non-null  int64
#  4   InvoiceDate        49782 non-null  datetime64[ns]
#  5   UnitPrice          49782 non-null  float64
#  6   CustomerID         49782 non-null  int32
#  7   Country            49782 non-null  object
#  8   Discount           49782 non-null  float64
#  9   PaymentMethod      49782 non-null  object
#  10  ShippingCost       49782 non-null  float64
#  11  Category           49782 non-null  object
#  12  SalesChannel       49782 non-null  object
#  13  ReturnStatus       49782 non-null  object
#  14  ShipmentProvider   49782 non-null  object
#  15  WarehouseLocation  49782 non-null  object
#  16  OrderPriority      49782 non-null  object
#  17  Sales              49782 non-null  float64
#  18  Sales_Discounted   49782 non-null  float64
#  19  Year               49782 non-null  int32
#  20  Quarter            49782 non-null  object
#  21  MonthNum           49782 non-null  int32
#  22  Month              49782 non-null  object
# dtypes: datetime64[ns](1), float64(5), int32(3), int64(2), object(12)
# memory usage: 8.2+ MB

# %% [markdown]
# ### 2.10 Sales in Year 2025 and 2024.
# As this report is compiled in 2024, it is not likely that we can generate a sales report that has records in 2025 and 2024.

# %%
#To handle this Year error, we will reverse the report timeframe to 2 years backwards. This will also ensure all records are in tact and analyzed.
df['Year'] = df['Year'] - 2

# %%
df['Year'].tail()
# Out:
# 49777    2023
# 49778    2023
# 49779    2023
# 49780    2023
# 49781    2023
# Name: Year, dtype: int32

# %%
df['InvoiceNo'].nunique()
# Out:
# 48494

# %% [markdown]
# # Online Sales Dataset Cleaning & Transformation completed and exporting to Power BI for further data analysis.

# %%
df.to_csv('cleandata.csv')
